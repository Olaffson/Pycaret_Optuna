# %% [markdown]
# # Test avec RandomForestRegressor

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("../data/silver.csv")

# %%
# column_titles = df.columns.tolist()
# column_titles

# %%
X = df.drop(["prix_median"], axis=1)
y = df['prix_median']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=True, random_state=42)

categorial_features = ["proximité_autoroute", "riviere"]

numerical_features = ['tx_crim', 'tx_residence','tx_commerce',
       'tx_nitriq', 'nb_piece', 'tx_ancienneté_parc_immo', 'distance_centre_emploi',
        'indice_impot_foncier',  'ratio_eleve_enseignant', 'tx_person_couleur',  'tx_status_sociaux_eco_inf']

categorical_transformer = OneHotEncoder(sparse_output=True)
numerical_transformer = StandardScaler()

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorial_features),
        ('num', numerical_transformer, numerical_features)
    ],
    remainder="passthrough" 
)

# Créer un objet CatBoostRegressor
cb_reg = RandomForestRegressor(random_state=42, verbose=False)


# Créer un pipeline avec le préprocesseur et le modèle CatBoostRegressor
pipe = Pipeline([
     ('preprocessor', preprocessor),
     ('cb_reg', cb_reg)
])

# Entraîner le pipeline sur les données d'entraînement
pipe.fit(X_train, y_train)
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

print("######## Mean squared error : ")
print("TRAIN :",mean_squared_error(y_train, y_pred_train))
print("TEST :",mean_squared_error(y_test, y_pred_test))
print("/////////////////////////////////////////////////////")

print("######## Mean absolute error : ")
print("TRAIN :",mean_absolute_error(y_train, y_pred_train))
print("TEST :",mean_absolute_error(y_test, y_pred_test))
print("/////////////////////////////////////////////////////")

print("######## R2 score : ")    
print("TRAIN :",r2_score(y_train, y_pred_train))
print("TEST :",r2_score(y_test, y_pred_test))
# Out:
# ######## Mean squared error :
# TRAIN : 1972396.5693069308
# TEST : 7806928.617647059
# /////////////////////////////////////////////////////
# ######## Mean absolute error :
# TRAIN : 908.1782178217821
# TEST : 2022.3823529411766
# /////////////////////////////////////////////////////
# ######## R2 score :
# TRAIN : 0.9772957374491794
# TEST : 0.8935425354971871

# %% [markdown]
# ### Optuna (recherche des hyperparametres)

# %%
import optuna
from sklearn.metrics import r2_score

# %%
def objective(trial):
    # Définition des hyperparamètres à optimiser
    n_estimators = trial.suggest_int('n_estimators', 100, 1000, step=100)
    max_depth = trial.suggest_int('max_depth', 5, 15)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    criterion = trial.suggest_categorical('criterion', ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'])
    max_features = trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2'])

    # Création du modèle avec les hyperparamètres suggérés
    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  min_samples_split=min_samples_split,
                                  min_samples_leaf=min_samples_leaf,
                                  criterion=criterion,
                                  max_features=max_features,
                                  random_state=42)
    
    # Entraînement du modèle
    model.fit(X_train, y_train)
    
    # Prédiction sur les données de test
    y_pred = model.predict(X_test)
    
    # Calcul du score R2
    r2 = r2_score(y_test, y_pred)
    
    return r2

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-06-12 14:15:56,021] A new study created in memory with name: no-name-6f53d227-8325-40ba-928a-05fabb5bfe2b
# [I 2023-06-12 14:15:56,799] Trial 0 finished with value: 0.8304564044416839 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'squared_error', 'max_features': 'log2'}. Best is trial 0 with value: 0.8304564044416839.
# [I 2023-06-12 14:15:57,659] Trial 1 finished with value: 0.8428654816460646 and parameters: {'n_estimators': 600, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'squared_error', 'max_features': 'log2'}. Best is trial 1 with value: 0.8428654816460646.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:15:58,538] Trial 2 finished with value: 0.8549666621983543 and parameters: {'n_estimators': 400, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 2 with value: 0.8549666621983543.
# [I 2023-06-12 14:15:59,057] Trial 3 finished with value: 0.814627894939642 and parameters: {'n_estimators': 400, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'friedman_mse', 'max_features': 'log2'}. Best is trial 2 with value: 0.8549666621983543.
# [I 2023-06-12 14:15:59,391] Trial 4 finished with value: 0.8280177427073033 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 3, 'criterion': 'absolute_error', 'max_features': 'log2'}. Best is trial 2 with value: 0.8549666621983543.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:02,080] Trial 5 finished with value: 0.8254504589006663 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 2 with value: 0.8549666621983543.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:03,834] Trial 6 finished with value: 0.8302753100044469 and parameters: {'n_estimators': 800, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 5, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 2 with value: 0.8549666621983543.
# [I 2023-06-12 14:16:04,797] Trial 7 finished with value: 0.8235434594090206 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 4, 'criterion': 'friedman_mse', 'max_features': 'sqrt'}. Best is trial 2 with value: 0.8549666621983543.
# [I 2023-06-12 14:16:05,731] Trial 8 finished with value: 0.8145407169049749 and parameters: {'n_estimators': 700, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 5, 'criterion': 'squared_error', 'max_features': 'sqrt'}. Best is trial 2 with value: 0.8549666621983543.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:16,092] Trial 9 finished with value: 0.8702001490999426 and parameters: {'n_estimators': 1000, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 9 with value: 0.8702001490999426.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:18,749] Trial 10 finished with value: 0.8792952767229483 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 10 with value: 0.8792952767229483.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:21,487] Trial 11 finished with value: 0.8792952767229483 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 10 with value: 0.8792952767229483.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:24,111] Trial 12 finished with value: 0.8792952767229483 and parameters: {'n_estimators': 1000, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 10 with value: 0.8792952767229483.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:26,500] Trial 13 finished with value: 0.8792009892501116 and parameters: {'n_estimators': 900, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 10 with value: 0.8792952767229483.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:29,010] Trial 14 finished with value: 0.8882924690045493 and parameters: {'n_estimators': 900, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 14 with value: 0.8882924690045493.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:31,280] Trial 15 finished with value: 0.8903533453424769 and parameters: {'n_estimators': 800, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 15 with value: 0.8903533453424769.
# [I 2023-06-12 14:16:32,522] Trial 16 finished with value: 0.8509666042930477 and parameters: {'n_estimators': 800, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'sqrt'}. Best is trial 15 with value: 0.8903533453424769.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:34,821] Trial 17 finished with value: 0.8903533453424769 and parameters: {'n_estimators': 800, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 15 with value: 0.8903533453424769.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:36,962] Trial 18 finished with value: 0.8902136842267632 and parameters: {'n_estimators': 700, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 15 with value: 0.8903533453424769.
# [I 2023-06-12 14:16:37,921] Trial 19 finished with value: 0.8423435682327248 and parameters: {'n_estimators': 600, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'poisson', 'max_features': 'sqrt'}. Best is trial 15 with value: 0.8903533453424769.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:39,886] Trial 20 finished with value: 0.8537850360650824 and parameters: {'n_estimators': 800, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 4, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 15 with value: 0.8903533453424769.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:41,894] Trial 21 finished with value: 0.8902136842267632 and parameters: {'n_estimators': 700, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 15 with value: 0.8903533453424769.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:44,145] Trial 22 finished with value: 0.8889543152570419 and parameters: {'n_estimators': 800, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 15 with value: 0.8903533453424769.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:45,914] Trial 23 finished with value: 0.8904625591194028 and parameters: {'n_estimators': 600, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 23 with value: 0.8904625591194028.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:47,639] Trial 24 finished with value: 0.8913805693295319 and parameters: {'n_estimators': 600, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 24 with value: 0.8913805693295319.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:48,970] Trial 25 finished with value: 0.8801410579723525 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 24 with value: 0.8913805693295319.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:50,685] Trial 26 finished with value: 0.8920310409186692 and parameters: {'n_estimators': 600, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:52,183] Trial 27 finished with value: 0.8683187717719045 and parameters: {'n_estimators': 600, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# [I 2023-06-12 14:16:53,798] Trial 28 finished with value: 0.8590268734676634 and parameters: {'n_estimators': 400, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'sqrt'}. Best is trial 26 with value: 0.8920310409186692.
# [I 2023-06-12 14:16:54,568] Trial 29 finished with value: 0.8562942339738342 and parameters: {'n_estimators': 500, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'squared_error', 'max_features': 'log2'}. Best is trial 26 with value: 0.8920310409186692.
# [I 2023-06-12 14:16:55,076] Trial 30 finished with value: 0.8621749111490978 and parameters: {'n_estimators': 300, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'log2'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:56,818] Trial 31 finished with value: 0.8914292053456303 and parameters: {'n_estimators': 600, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:58,576] Trial 32 finished with value: 0.8914292053456303 and parameters: {'n_estimators': 600, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:16:59,977] Trial 33 finished with value: 0.8824692722670828 and parameters: {'n_estimators': 500, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:01,691] Trial 34 finished with value: 0.8907551525184503 and parameters: {'n_estimators': 600, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# [I 2023-06-12 14:17:02,284] Trial 35 finished with value: 0.8382893857761142 and parameters: {'n_estimators': 400, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3, 'criterion': 'friedman_mse', 'max_features': 'log2'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:03,018] Trial 36 finished with value: 0.8634418568512878 and parameters: {'n_estimators': 300, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:09,483] Trial 37 finished with value: 0.8872201090764014 and parameters: {'n_estimators': 600, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# [I 2023-06-12 14:17:10,262] Trial 38 finished with value: 0.8480210872713396 and parameters: {'n_estimators': 500, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'log2'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:11,763] Trial 39 finished with value: 0.874323025622135 and parameters: {'n_estimators': 700, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 1, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:12,684] Trial 40 finished with value: 0.8405124078666045 and parameters: {'n_estimators': 400, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 4, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:14,387] Trial 41 finished with value: 0.8907551525184503 and parameters: {'n_estimators': 600, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 26 with value: 0.8920310409186692.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:16,390] Trial 42 finished with value: 0.8923116162641817 and parameters: {'n_estimators': 700, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 42 with value: 0.8923116162641817.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:18,323] Trial 43 finished with value: 0.8920231323617803 and parameters: {'n_estimators': 700, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 42 with value: 0.8923116162641817.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:20,339] Trial 44 finished with value: 0.8915243585898167 and parameters: {'n_estimators': 700, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 42 with value: 0.8923116162641817.
# [I 2023-06-12 14:17:22,743] Trial 45 finished with value: 0.8253507364376799 and parameters: {'n_estimators': 700, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 3, 'criterion': 'absolute_error', 'max_features': 'sqrt'}. Best is trial 42 with value: 0.8923116162641817.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:23,063] Trial 46 finished with value: 0.8946067974997578 and parameters: {'n_estimators': 100, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:23,333] Trial 47 finished with value: 0.8494352616557097 and parameters: {'n_estimators': 100, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 5, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:23,640] Trial 48 finished with value: 0.891736213547906 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:23,921] Trial 49 finished with value: 0.8719599313652457 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# [I 2023-06-12 14:17:24,253] Trial 50 finished with value: 0.8498627309671868 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'log2'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:24,858] Trial 51 finished with value: 0.8899105238282932 and parameters: {'n_estimators': 200, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:25,424] Trial 52 finished with value: 0.8819770004708708 and parameters: {'n_estimators': 200, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:28,398] Trial 53 finished with value: 0.8901605765014647 and parameters: {'n_estimators': 900, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 46 with value: 0.8946067974997578.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:28,720] Trial 54 finished with value: 0.8949142921897552 and parameters: {'n_estimators': 100, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:29,009] Trial 55 finished with value: 0.874431290290641 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 3, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# [I 2023-06-12 14:17:29,344] Trial 56 finished with value: 0.8549234708126551 and parameters: {'n_estimators': 200, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'sqrt'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:29,647] Trial 57 finished with value: 0.890602388943312 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 2, 'criterion': 'poisson', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:30,413] Trial 58 finished with value: 0.8723142622159116 and parameters: {'n_estimators': 300, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:31,488] Trial 59 finished with value: 0.8933205935096498 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:32,558] Trial 60 finished with value: 0.8933205935096498 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:34,689] Trial 61 finished with value: 0.8819159676100603 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:35,780] Trial 62 finished with value: 0.8901956097371375 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:36,885] Trial 63 finished with value: 0.8933205935096498 and parameters: {'n_estimators': 100, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:37,908] Trial 64 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:38,932] Trial 65 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:39,905] Trial 66 finished with value: 0.888793902760348 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# [I 2023-06-12 14:17:40,619] Trial 67 finished with value: 0.8345306324530646 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'sqrt'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:41,693] Trial 68 finished with value: 0.8925745692756053 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:43,783] Trial 69 finished with value: 0.8849788556571845 and parameters: {'n_estimators': 200, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:44,811] Trial 70 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:45,834] Trial 71 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:46,861] Trial 72 finished with value: 0.8899842310203665 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:48,795] Trial 73 finished with value: 0.8790836609443375 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:49,809] Trial 74 finished with value: 0.8899842310203665 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:50,739] Trial 75 finished with value: 0.8889509180739533 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# [I 2023-06-12 14:17:51,441] Trial 76 finished with value: 0.8335479684356096 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'log2'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:54,115] Trial 77 finished with value: 0.8271453282577467 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 4, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:55,107] Trial 78 finished with value: 0.888793902760348 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:56,794] Trial 79 finished with value: 0.8763729318416811 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:57,830] Trial 80 finished with value: 0.8915134805637398 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:58,888] Trial 81 finished with value: 0.8925745692756053 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:17:59,916] Trial 82 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:00,946] Trial 83 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:02,959] Trial 84 finished with value: 0.8814894009919961 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:04,065] Trial 85 finished with value: 0.8915134805637398 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# [I 2023-06-12 14:18:04,776] Trial 86 finished with value: 0.844811733100312 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'sqrt'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:05,762] Trial 87 finished with value: 0.8873291085702683 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:06,697] Trial 88 finished with value: 0.8893936503849693 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:06,962] Trial 89 finished with value: 0.872082174747496 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 2, 'criterion': 'friedman_mse', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# [I 2023-06-12 14:18:07,692] Trial 90 finished with value: 0.8330227760104176 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'log2'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:08,757] Trial 91 finished with value: 0.8925745692756053 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:09,756] Trial 92 finished with value: 0.888793902760348 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:10,835] Trial 93 finished with value: 0.8925745692756053 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:11,872] Trial 94 finished with value: 0.8934155584685781 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:12,382] Trial 95 finished with value: 0.8837174134728406 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 1, 'criterion': 'squared_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:13,372] Trial 96 finished with value: 0.888793902760348 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:14,420] Trial 97 finished with value: 0.8915134805637398 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:16,439] Trial 98 finished with value: 0.8814894009919961 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.
# /home/apprenant/miniconda3/envs/sklearn-env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [I 2023-06-12 14:18:17,444] Trial 99 finished with value: 0.888793902760348 and parameters: {'n_estimators': 100, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1, 'criterion': 'absolute_error', 'max_features': 'auto'}. Best is trial 54 with value: 0.8949142921897552.

# %%
best_params = study.best_params
best_value = study.best_value

# %%
print(best_params)
print(best_value)
# Out:
# {'n_estimators': 100, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 1, 'criterion': 'poisson', 'max_features': 'auto'}
# 0.8949142921897552
