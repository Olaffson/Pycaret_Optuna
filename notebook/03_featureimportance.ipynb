# %%
import pandas as pd

# %%
df = pd.read_csv('../data/silver.csv')

# %%
# Suppression des colonnes 'riviere', 'proximité_autoroute' et 'tx_residence'
df_new = df.drop(['riviere', 'tx_person_couleur', 'tx_person_couleur'], axis=1)

# %%
df_new.to_csv('../data/gold.csv', index=False)

# %%
df_new
# Out:
#      tx_crim  tx_commerce  tx_nitriq  nb_piece  tx_ancienneté_parc_immo  \
# 0    0.00632         2.31      0.538     6.575                     65.2
# 1    0.02731         7.07      0.469     6.421                     78.9
# 2    0.02729         7.07      0.469     7.185                     61.1
# 3    0.03237         2.18      0.458     6.998                     45.8
# 4    0.06905         2.18      0.458     7.147                     54.2
# ..       ...          ...        ...       ...                      ...
# 501  0.06263        11.93      0.573     6.593                     69.1
# 502  0.04527        11.93      0.573     6.120                     76.7
# 503  0.06076        11.93      0.573     6.976                     91.0
# 504  0.10959        11.93      0.573     6.794                     89.3
# 505  0.04741        11.93      0.573     6.030                     80.8
#
#      distance_centre_emploi  indice_impot_foncier  ratio_eleve_enseignant  \
# ...
