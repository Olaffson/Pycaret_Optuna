# %%
import pandas as pd
from pycaret.regression import *

# %%
df_new = pd.read_csv('../data/gold.csv')

# %%
reg_setup = setup(data=df_new, target='prix_median', train_size=0.8)
# Out:
# <style type="text/css">
# #T_45264_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_45264">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45264_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_45264_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45264_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45264_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_45264_row0_col1" class="data row0 col1" >767</td>
#     </tr>
#     <tr>
#       <th id="T_45264_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45264_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_45264_row1_col1" class="data row1 col1" >prix_median</td>
#     </tr>
#     <tr>
#       <th id="T_45264_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_3b1f4 th {
#   text-align: left;
# }
# ...

# %%
final_model = finalize_model(best_model)

# %%
predictions = predict_model(final_model, data=df_new)
# Out:
# <style type="text/css">
# </style>
# <table id="T_664e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_664e2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_664e2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_664e2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_664e2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_664e2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_664e2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_664e2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_664e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_664e2_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_664e2_row0_col1" class="data row0 col1" >436.3876</td>
# ...

# %% [markdown]
# ### CatBoost Regressor

# %%
model_catboost = create_model('catboost')
# Out:
# <style type="text/css">
# #T_72fcb_row10_col0, #T_72fcb_row10_col1, #T_72fcb_row10_col2, #T_72fcb_row10_col3, #T_72fcb_row10_col4, #T_72fcb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_72fcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72fcb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_72fcb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_72fcb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_72fcb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_72fcb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_72fcb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_model_catboost = tune_model(model_catboost)
# Out:
# <style type="text/css">
# #T_8613d_row10_col0, #T_8613d_row10_col1, #T_8613d_row10_col2, #T_8613d_row10_col3, #T_8613d_row10_col4, #T_8613d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8613d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8613d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8613d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8613d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8613d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8613d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8613d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_model_catboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
model_gbr = create_model('gbr')
# Out:
# <style type="text/css">
# #T_07314_row10_col0, #T_07314_row10_col1, #T_07314_row10_col2, #T_07314_row10_col3, #T_07314_row10_col4, #T_07314_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_07314">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07314_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_07314_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_07314_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_07314_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_07314_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_07314_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_model_gbr = tune_model(model_gbr)
# Out:
# <style type="text/css">
# #T_bb6ce_row10_col0, #T_bb6ce_row10_col1, #T_bb6ce_row10_col2, #T_bb6ce_row10_col3, #T_bb6ce_row10_col4, #T_bb6ce_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bb6ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb6ce_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bb6ce_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bb6ce_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bb6ce_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bb6ce_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bb6ce_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_model_gbr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### RandomForestRegressor

# %%
model_rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_247aa_row10_col0, #T_247aa_row10_col1, #T_247aa_row10_col2, #T_247aa_row10_col3, #T_247aa_row10_col4, #T_247aa_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_247aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_247aa_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_247aa_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_247aa_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_247aa_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_247aa_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_247aa_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_model_rf = tune_model(model_rf)
# Out:
# <style type="text/css">
# #T_064e3_row10_col0, #T_064e3_row10_col1, #T_064e3_row10_col2, #T_064e3_row10_col3, #T_064e3_row10_col4, #T_064e3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_064e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_064e3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_064e3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_064e3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_064e3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_064e3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_064e3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_model_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
